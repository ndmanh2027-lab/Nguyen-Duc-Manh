# %% [markdown]
# # W3A1

# %%
n = int(input())
while n >0:
    a = n % 10
    print(a, end="")
    n = n // 10
# Out:
# 987654321

# %% [markdown]
# # W3A2

# %%
a,b = map(int,input().split())
a,b = b,a
print(a,b)
# Out:
# 5 4

# %% [markdown]
# # W3A3

# %%
n = int(input())
if n & (n-1) == 0:
    print(f"{n} là số nguyên dương và là lũy thừa của 2")
else:
    print(f"{n} không phải là số nguyên dương và là lũy thừa của 2")
# Out:
# 8 là số nguyên dương và là lũy thừa của 2

# %% [markdown]
# # W3A4

# %%
m, n = map(int,input().split())
print('m // n =', m//n)
# Out:
# m // n = 2

# %% [markdown]
# # W3A5

# %%
m, n = map(int,input().split())
if m % n ==0:
    print('m / n = ', m/n)
else:
    print('m / n = ',(m//n)+1)
# Out:
# m / n =  3

# %% [markdown]
# # W3A6

# %%
x = int(input())
if x % 2 == 0:
    print(f"{x} là số chẵn")
else:
    print(f"{x} là số lẻ")
# Out:
# 8 là số chẵn

# %% [markdown]
# # W3A7

# %%
a, b = map(int,input().split())
if a < 0 and b < 0:
    print('Yes')
else:
    print('No')
# Out:
# Yes

# %% [markdown]
# # W3A8

# %%
a = input()
b = input()
if len(a)>len(b):
    print('True')
else:
    print('False')
# Out:
# True

# %% [markdown]
# # W3A9

# %%
a, b, c = map(int,input().split())
if a + b > c and a + c > b and b + c > a:
    print('Yes')
else:
    print('No')
# Out:
# Yes

# %% [markdown]
# # W3A10

# %%
a, b, c, d = map(int,input().split())
print(max(a,b,c,d))
# Out:
# 4

# %% [markdown]
# # W3A11

# %%
a, b, c = map(int,input().split())
if a + b > c and a + c > b and b + c > a:
    if a == b == c:
        print('Tam giác đều')
    elif a == b or a == c or b == c:
        print('Tam giác cân')
    else:
        print('Tam giác thường')
else:
    print('Không phải là 3 cạnh của tam giác')
# Out:
# Tam giác cân

# %% [markdown]
# # W3A12

# %%
n = int(input())
if n % 400 == 0 or (n % 4 == 0 and n % 100 != 0):
    print('Yes')
else:
    print('No')
# Out:
# Yes

# %% [markdown]
# # W3A14

# %%
a, b = map(int,input().split())
if a == 0 and b == 0:
    print('Vô số nghiệm')
elif a == 0 and b != 0:
    print('Vô nghiệm')
else:
    print(f'x = {-b / a}')
# Out:
# x = -9.0

# %% [markdown]
# # W3A15

# %%
n = int(input())
if 0 <= n < 5:
    print('Yếu')
elif 5 <= n < 6.5:
    print('Trung bình')
elif 6.5 <= n < 8:
    print('Khá')
elif 8 <= n <= 10:
    print('Giỏi')
else:
    pass
# Out:
# Giỏi

# %% [markdown]
# # W3A16

# %%
a = float(input())
print(int(a)+1)
print(int(a))
if a - int(a) >= 0.5:
    print(int(a)+1)
else: 
    print(int(a))
# Out:
# 7
# 6
# 7

# %% [markdown]
# # W3A17

# %%
a,  b, c, d = map(int,input().split())
m = b / a
if m % 1 == 0 and c == b * m and d == c * m:
    print(f'{a}, {b}, {c}, {d} là một cấp số nhân')
else:
    print(f'{a}, {b}, {c}, {d} không phải là một cấp số nhân')
# Out:
# 2, 4, 8, 16 là một cấp số nhân
