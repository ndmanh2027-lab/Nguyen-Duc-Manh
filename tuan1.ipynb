# %% [markdown]
# # Bài 1

# %%
n = int(input())
print(n*2)
# Out:
# 10

# %% [markdown]
# # Bài 2

# %%
a, b = map(int, input().split())
sv = a * b
st = (a/2)**2 * 3.14
s = sv - st
print(s)
# Out:
# 21.5

# %% [markdown]
# # Bài 3

# %%
a = input()
ma_a = ord(a)
if 65 <= ma_a <= 90:
    print(chr(ma_a + 32))
elif 97 <= ma_a <= 122:
    print(chr(ma_a - 32))
else:
    pass
# Out:
# D

# %% [markdown]
# # Bài 4

# %%
a = input()
ma_a = ord(a)
if 65 <= ma_a <= 90 or 97 <= ma_a <= 122:
    print(f"{a} là kí tự alphabet")
else:
    print(f"{a} không phải kí tự alphabet")
# Out:
# f là kí tự alphabet

# %% [markdown]
# # Bài 5

# %%
a = input()
if ord(a) == 65:
    print("Đây là trường hợp đặc biệt")
else:
 print(chr(ord(a)+31))
# Out:
# Đây là trường hợp đặc biệt

# %% [markdown]
# # Bài 6

# %%
a, b, c = map(int, input().split())
p = (a + b + c)/2
if a + b > c and a + c > b and c + b > a:
    s = (p*(p-a)*(p-b)*(p-c))**0.5
    print(round(s, 1))
else:
    print('Không phải 3 cạnh của tam giác')
# Out:
# 6.0

# %% [markdown]
# # Bài 7

# %%
chuoi = input()
if len(chuoi) >= 20:
    print(chuoi[4], chuoi[8])
else:
    print('Chuỗi quá ngắn')
# Out:
# t o

# %% [markdown]
# # Bài 8

# %%
ten_ho = input()
a, b = map(int, input().split())
so_dien = b - a
if 0<= so_dien <= 50:
    tien = so_dien * 1984
elif 50< so_dien <= 100:
    tien = 50 * 1984 + (so_dien-50)*2050
elif 100< so_dien <= 200:
    tien = 50 * 1984 + 50 * 2050 + (so_dien-100)*2380
elif 200< so_dien <= 300:
    tien = 50* 1984 + 50* 2050 + 100* 2300 + (so_dien-200)*2998
elif 300< so_dien <= 400:
    tien = 50* 1984 + 50 * 2050 + 100* 2300 + 100* 2998 + (so_dien-300)*3350
elif so_dien > 400:
    tien = 50 * 1984 + 50 * 2050 + 100 * 2300 + 100 * 2998 + 100*3350 + (so_dien-400)*3460
else:
    pass
print(ten_ho)
print(int(tien*1.08))
# Out:
# abc
# 1899180

# %% [markdown]
# # Bài 1-2

# %%
a = int(input())
if a % 2 == 0:
    print(f"{a} là số chẵn")
else:
    print(f"{a} là số lẻ")
# Out:
# 8 là số chẵn

# %% [markdown]
# # Bài 2-2

# %%
a = int(input())
if a % 5 == 0 and a % 2 ==1:
    print('True')
else:
    print('False')
# Out:
# False

# %% [markdown]
# # Bài 3-2

# %%
a = int(input())
if a % 3 == 0 and a %5 ==0:
    print('True')
else:
    print('False')
# Out:
# True

# %% [markdown]
# # Bài 4-2

# %%
a = int(input())
if 2026 - a >= 18:
    print('Đủ điều kiện')
else:
    print('Không đủ điều kiện')
# Out:
# Không đủ điều kiện

# %% [markdown]
# # Bài 5-2

# %%
a, b = map(int, input().split())
if a > b:
    print(a)
elif b > a:
    print(b)
else:
    print('Hai số bằng nhau')
# Out:
# 7

# %% [markdown]
# # Bài 6-2

# %%
a = input()
if 48 <= ord(a) <= 57:
    print('Số')
elif 65 <= ord(a) <= 90 or 97 <= ord(a) <= 122:
    print('Chữ')
else:
  pass
# Out:
# Chữ

# %% [markdown]
# # Bài 7-2

# %%
a = int(input())
if 0 <= a < 5:
    print('Yếu')
elif 5 <= a < 6.5:
    print('Trung bình')
elif 6.5 <= a <8:
    print('Khá')
elif 8 <= a <=10:
    print('Giỏi')
else:
    pass
# Out:
# Giỏi

# %% [markdown]
# # Bài 8-2

# %%
a = int(input())
if a % 400 ==0 or ( a%4==0 and a%100 != 0):
    print(f"{a} là năm nhuận")
else:
    print(f"{a} không phải năm nhuận")
# Out:
# 2024 là năm nhuận
