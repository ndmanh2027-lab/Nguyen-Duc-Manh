# %% [markdown]
# # W2A1

# %%
print('Hello World!')
# Out:
# Hello World!

# %% [markdown]
# # W2A2

# %%
ten = input()
print('Xin chào ' + ten)
# Out:
# Xin chào Mạnh

# %% [markdown]
# # W2A3

# %%
a, b = map(int, input().split())
print('a + b = ' + str(a + b))
print('a - b = ' + str(a - b))
print('a * b = ' + str(a * b))
print('a // b = ' + str(a // b))
print('a % b = ' + str(a % b))
print('a / b =' + str(round(a / b, 2)))
# Out:
# a + b = 13
# a - b = 7
# a * b = 30
# a // b = 3
# a % b = 1
# a / b =3.33

# %% [markdown]
# # W2A4

# %%
a1, b1, c1, a2, b2, a3 = map(int, input().split())
tb = (a1 + b1 + c1 + a2*2 + b2*2 + a3*3) / 10
print('Điểm trung bình = ' + str(round(tb, 2)))
# Out:
# Điểm trung bình = 6.8

# %% [markdown]
# # W2A5

# %%
a, b = map(int, input().split())
print('a ^ b = ' + str(a ** b))
# Out:
# a ^ b = 8

# %% [markdown]
# # W2A6

# %%
a = input()
print(ord(a))
print(chr(ord(a)-32))
# Out:
# 97
# A

# %% [markdown]
# # W2A7

# %%
A = ((13**2)*3)+5
B = 13**2*3 + 5
print(A)
print(B)
# Out:
# 512
# 512

# %% [markdown]
# # W2A8

# %%
c = int(input())
F = 9/5*c + 32
print('Nhiệt độ F = ' + str(round(F, 2)))
# Out:
# Nhiệt độ F = 89.6

# %% [markdown]
# # W2A9

# %%
x = int(input())
tien = x*1.4 + 10
print(round(tien, 2))
# Out:
# 150.0

# %% [markdown]
# # W2A10

# %%
ten1 = input()
ten2 = input()
ten3 = input()
loi_chao = f"Hi {ten3}, {ten2} and {ten1}"
print(loi_chao)

# %% [markdown]
# # W2A11

# %%
h = int(input())
m = int(input())
s = h*3600 + m*60
quy_doi = f"{h} giờ {m} phút bằng {s} giây"
print(quy_doi)
# Out:
# 1 giờ 56 phút bằng 6960 giây

# %% [markdown]
# # W2A12

# %%
n = int(input())
so_mieng_dan = n*6
print(so_mieng_dan)

# %% [markdown]
# # W2A13

# %%
a, b = map(int, input().split())
if a >0 and b > 0:
  print((a*b)%10)
else:
  pass
# Out:
# 2

# %% [markdown]
# # W2A14

# %%
a, b = map(int, input().split())
a = a + b
b = a - b
a = a - b
print(a, b)
# Out:
# 5 4

# %% [markdown]
# # W2A15

# %% [markdown]
# # W2A16

# %%
print('Spring\nSummer\nAutumn\nWinter')
# Out:
# Spring
# Summer
# Autumn
# Winter

# %% [markdown]
# # W2A17

# %%
print('*\n***\n*****')
# Out:
# *
# ***
# *****

# %% [markdown]
# # W2A18

# %%
print('###   # #      ### ###\n #    #    #    #    # \n #    #     #   #    # \n #    #    #    #    # \n #    # #       #    # ')
# Out:
# ###   # #      ### ###
#  #    #    #    #    #
#  #    #     #   #    #
#  #    #    #    #    #
#  #    # #       #    #

# %% [markdown]
# # W2A19

# %%
print('Monday\nTuesday\nWednesday\nThursday\nFriday\nSaturday\nSunday')
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %% [markdown]
# # W2A20

# %%
print('January\nFebruary\nMarch\nApril\nMay\nJune\nJuly\nAugust\nSeptember\nOctober\nNovember\nDecember')
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %% [markdown]
# # W2A21

# %%
for i in range(11):
    print('Hello World')
# Out:
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
